# %%
# Part 1
#1. What is the outcome?
#How likely free-tier customers will covert to paying customers.

#2. What are the predictors/covariates?
#Demographic data collected at signup (age, gender, location, and profession) 
#and customer useage data (days since last log in, and activity score 1 = active user, 0= inactive user)

#3. What timeframe is this data relevent for?
#Jan-Apr 2015

#4. What is the hypothesis?
#Customers who were more recently active are more likely to convert to paying customers.


#Part 2
import pandas as pd
import statsmodels.api as sm
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("/Users/shenyanfang/Desktop/GA DATA SCIENCE/00_GA_Week1/lesson-01/project-1/assets/admissions.csv")
df.head()
df.describe()

#Data dictionary
#Admit(categorical): 0 = not admitted 1 = admitted
#GRE(continuous): 0-800
#GPA(continuous): 0-4
#Prestige of undergraduate school(categorical): 1= not prestigious 2 = low prestige 3= good prestige 4= high prestige


#1. What is the outcome?
#Admission into grad school

#2. What are the predictors/covariates?
#GRE, GPA, Prestige of undergraduate school

#3. What timeframe is this data relevent for?
#Not defined in the problem(could be a potential limitation of the dataset).

#4. What is the hypothesis?
#Students have higher GRE scores/GPA will have higher admissions rates into graduate school.

#Part 3:
#1. What are the goals of the exploratory analysis?
#Understand the main characteristics of a dataset; check missing data, outliers, distributions of the variables, etc.; 

#2a. What are the assumptions of the distribution of data?
#Normality

#2b. How will determine the distribution of your data?
#Answer: start with a histograms

#3a. How might outliers impact your analysis?
#Answer: results may be skewed by extremities

#3b. How will you test for outliers?
#Box plots

#4a. What is colinearity?
#A phenomenon in which two or more predictor variables in a multiple regression model are highly correlated, 
#meaning that one can be linearly predicted from the others with a substantial degree of accuracy.

#4b. How will you test for colinearity?
#Correlation matrix

#5. What is your exploratory analysis plan?
#Check missing data, outliers, normal distribution, and colinearity
# Out:
#             admit         gre        gpa    prestige
# count  400.000000  398.000000  398.00000  399.000000
# mean     0.317500  588.040201    3.39093    2.486216
# std      0.466087  115.628513    0.38063    0.945333
# min      0.000000  220.000000    2.26000    1.000000
# 25%      0.000000  520.000000    3.13000    2.000000
# 50%      0.000000  580.000000    3.39500    2.000000
# 75%      1.000000  660.000000    3.67000    3.000000
# max      1.000000  800.000000    4.00000    4.000000
