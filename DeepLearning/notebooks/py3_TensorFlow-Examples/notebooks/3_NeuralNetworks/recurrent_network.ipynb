# %% [markdown]
# '''
# A Reccurent Neural Network (LSTM) implementation example using TensorFlow library.
# This example is using the MNIST database of handwritten digits (http://yann.lecun.com/exdb/mnist/)
# Long Short Term Memory paper: http://deeplearning.cs.cmu.edu/pdfs/Hochreiter97_lstm.pdf
#
# Author: Aymeric Damien
# Project: https://github.com/aymericdamien/TensorFlow-Examples/
# '''

# %%
import tensorflow as tf
from tensorflow.contrib import rnn
import numpy as np

# Import MINST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# '''
# To classify images using a reccurent neural network, we consider every image
# row as a sequence of pixels. Because MNIST image shape is 28*28px, we will then
# handle 28 sequences of 28 steps for every sample.
# '''

# %%
# Parameters
learning_rate = 0.001
training_iters = 100000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 28 # MNIST data input (img shape: 28*28)
n_steps = 28 # timesteps
n_hidden = 128 # hidden layer num of features
n_classes = 10 # MNIST total classes (0-9 digits)

# tf Graph input
x = tf.placeholder("float", [None, n_steps, n_input])
y = tf.placeholder("float", [None, n_classes])

# Define weights
weights = {
    'out': tf.Variable(tf.random_normal([n_hidden, n_classes]))
}
biases = {
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# %%
def RNN(x, weights, biases):

    # Prepare data shape to match `rnn` function requirements
    # Current data input shape: (batch_size, n_steps, n_input)
    # Required shape: 'n_steps' tensors list of shape (batch_size, n_input)
    
    # Unstack to get a list of 'n_steps' tensors of shape (batch_size, n_input)
    x = tf.unstack(x, n_steps, 1)

    # Define a lstm cell with tensorflow
    lstm_cell = rnn.BasicLSTMCell(n_hidden, forget_bias=1.0)

    # Get lstm cell output
    outputs, states = rnn.static_rnn(lstm_cell, x, dtype=tf.float32)

    # Linear activation, using rnn inner loop last output
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

pred = RNN(x, weights, biases)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Reshape data to get 28 seq of 28 elements
        batch_x = batch_x.reshape((batch_size, n_steps, n_input))
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y})
        if step % display_step == 0:
            # Calculate batch accuracy
            acc = sess.run(accuracy, feed_dict={x: batch_x, y: batch_y})
            # Calculate batch loss
            loss = sess.run(cost, feed_dict={x: batch_x, y: batch_y})
            print ("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")

    # Calculate accuracy for 128 mnist test images
    test_len = 128
    test_data = mnist.test.images[:test_len].reshape((-1, n_steps, n_input))
    test_label = mnist.test.labels[:test_len]
    print ("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: test_data, y: test_label}))
# Out:
# Iter 1280, Minibatch Loss= 1.784954, Training Accuracy= 0.35938
# Iter 2560, Minibatch Loss= 1.457495, Training Accuracy= 0.51562
# Iter 3840, Minibatch Loss= 1.304512, Training Accuracy= 0.61719
# Iter 5120, Minibatch Loss= 1.041872, Training Accuracy= 0.67188
# Iter 6400, Minibatch Loss= 0.726328, Training Accuracy= 0.75000
# Iter 7680, Minibatch Loss= 0.950083, Training Accuracy= 0.71875
# Iter 8960, Minibatch Loss= 0.535922, Training Accuracy= 0.81250
# Iter 10240, Minibatch Loss= 0.595868, Training Accuracy= 0.80469
# Iter 11520, Minibatch Loss= 0.565680, Training Accuracy= 0.79688
# Iter 12800, Minibatch Loss= 0.399199, Training Accuracy= 0.86719
# Iter 14080, Minibatch Loss= 0.282264, Training Accuracy= 0.89844
# Iter 15360, Minibatch Loss= 0.506843, Training Accuracy= 0.85156
# Iter 16640, Minibatch Loss= 0.270713, Training Accuracy= 0.94531
# Iter 17920, Minibatch Loss= 0.351888, Training Accuracy= 0.87500
# Iter 19200, Minibatch Loss= 0.329104, Training Accuracy= 0.88281
# Iter 20480, Minibatch Loss= 0.343000, Training Accuracy= 0.89844
# Iter 21760, Minibatch Loss= 0.185199, Training Accuracy= 0.95312
# Iter 23040, Minibatch Loss= 0.295744, Training Accuracy= 0.90625
# Iter 24320, Minibatch Loss= 0.223025, Training Accuracy= 0.92969
# Iter 25600, Minibatch Loss= 0.185989, Training Accuracy= 0.93750
# Iter 26880, Minibatch Loss= 0.251526, Training Accuracy= 0.93750
# Iter 28160, Minibatch Loss= 0.126289, Training Accuracy= 0.96094
# Iter 29440, Minibatch Loss= 0.127257, Training Accuracy= 0.93750
# Iter 30720, Minibatch Loss= 0.207249, Training Accuracy= 0.92188
# Iter 32000, Minibatch Loss= 0.244294, Training Accuracy= 0.93750
# Iter 33280, Minibatch Loss= 0.079262, Training Accuracy= 0.96875
# Iter 34560, Minibatch Loss= 0.118862, Training Accuracy= 0.96875
# Iter 35840, Minibatch Loss= 0.195048, Training Accuracy= 0.95312
# Iter 37120, Minibatch Loss= 0.186699, Training Accuracy= 0.92969
# Iter 38400, Minibatch Loss= 0.285340, Training Accuracy= 0.91406
# Iter 39680, Minibatch Loss= 0.218873, Training Accuracy= 0.93750
# Iter 40960, Minibatch Loss= 0.066487, Training Accuracy= 0.98438
# Iter 42240, Minibatch Loss= 0.266151, Training Accuracy= 0.91406
# Iter 43520, Minibatch Loss= 0.277356, Training Accuracy= 0.91406
# Iter 44800, Minibatch Loss= 0.168782, Training Accuracy= 0.94531
# Iter 46080, Minibatch Loss= 0.168523, Training Accuracy= 0.96094
# Iter 47360, Minibatch Loss= 0.348939, Training Accuracy= 0.91406
# Iter 48640, Minibatch Loss= 0.172280, Training Accuracy= 0.93750
# Iter 49920, Minibatch Loss= 0.137029, Training Accuracy= 0.93750
# Iter 51200, Minibatch Loss= 0.154889, Training Accuracy= 0.94531
# Iter 52480, Minibatch Loss= 0.112511, Training Accuracy= 0.95312
# Iter 53760, Minibatch Loss= 0.160792, Training Accuracy= 0.95312
# Iter 55040, Minibatch Loss= 0.245336, Training Accuracy= 0.92188
# Iter 56320, Minibatch Loss= 0.148946, Training Accuracy= 0.96094
# Iter 57600, Minibatch Loss= 0.184503, Training Accuracy= 0.96094
# Iter 58880, Minibatch Loss= 0.204393, Training Accuracy= 0.94531
# Iter 60160, Minibatch Loss= 0.074501, Training Accuracy= 0.97656
# Iter 61440, Minibatch Loss= 0.107863, Training Accuracy= 0.97656
# Iter 62720, Minibatch Loss= 0.131379, Training Accuracy= 0.93750
# Iter 64000, Minibatch Loss= 0.144038, Training Accuracy= 0.95312
# Iter 65280, Minibatch Loss= 0.144495, Training Accuracy= 0.96875
# Iter 66560, Minibatch Loss= 0.105023, Training Accuracy= 0.96094
# Iter 67840, Minibatch Loss= 0.088880, Training Accuracy= 0.97656
# Iter 69120, Minibatch Loss= 0.110928, Training Accuracy= 0.96875
# Iter 70400, Minibatch Loss= 0.114612, Training Accuracy= 0.96094
# Iter 71680, Minibatch Loss= 0.074468, Training Accuracy= 0.96875
# Iter 72960, Minibatch Loss= 0.172933, Training Accuracy= 0.96094
# Iter 74240, Minibatch Loss= 0.092317, Training Accuracy= 0.95312
# Iter 75520, Minibatch Loss= 0.077538, Training Accuracy= 0.99219
# Iter 76800, Minibatch Loss= 0.083417, Training Accuracy= 0.96875
# Iter 78080, Minibatch Loss= 0.130463, Training Accuracy= 0.95312
# Iter 79360, Minibatch Loss= 0.073217, Training Accuracy= 0.98438
# Iter 80640, Minibatch Loss= 0.090933, Training Accuracy= 0.96094
# Iter 81920, Minibatch Loss= 0.122528, Training Accuracy= 0.97656
# Iter 83200, Minibatch Loss= 0.090826, Training Accuracy= 0.97656
# Iter 84480, Minibatch Loss= 0.154198, Training Accuracy= 0.95312
# Iter 85760, Minibatch Loss= 0.091145, Training Accuracy= 0.97656
# Iter 87040, Minibatch Loss= 0.186265, Training Accuracy= 0.93750
# Iter 88320, Minibatch Loss= 0.083083, Training Accuracy= 0.96875
# Iter 89600, Minibatch Loss= 0.117964, Training Accuracy= 0.96875
# Iter 90880, Minibatch Loss= 0.073305, Training Accuracy= 0.97656
# Iter 92160, Minibatch Loss= 0.034345, Training Accuracy= 0.99219
# Iter 93440, Minibatch Loss= 0.169902, Training Accuracy= 0.94531
# Iter 94720, Minibatch Loss= 0.239199, Training Accuracy= 0.92188
# Iter 96000, Minibatch Loss= 0.084393, Training Accuracy= 0.99219
# Iter 97280, Minibatch Loss= 0.091291, Training Accuracy= 0.96875
# Iter 98560, Minibatch Loss= 0.081606, Training Accuracy= 0.97656
# Iter 99840, Minibatch Loss= 0.091287, Training Accuracy= 0.97656
# Optimization Finished!
# Testing Accuracy: 0.992188
